# %%
# Select only the columns with names, latitude, and longitude
cleaned_df = df[['wellnessCentreName', 'latitude', 'longitude']]

# Display the cleaned data
cleaned_df.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 2
#       1 # Select only the columns with names, latitude, and longitude
# ----> 2 cleaned_df = df[['wellnessCentreName', 'latitude', 'longitude']]
#       4 # Display the cleaned data
#       5 cleaned_df.head()
#
# NameError: name 'df' is not defined

# %%
import pandas as pd

df = pd.read_csv("Hospitals In India (Anonymized).csv")
cleaned = df[['id', 'Latitude', 'Longitude']].rename(columns={
    'id': 'name', 'Latitude': 'latitude', 'Longitude': 'longitude'
})
cleaned.to_csv("cleaned_hospitals.csv", index=False)

# %%
# Strip whitespace from column names
df = pd.read_csv("bbmp-parks-2016.csv")
df.columns = df.columns.str.strip()

# Now select and rename the relevant columns
cleaned_df = df[['Park Name', 'Latitude', 'Longitude']].rename(columns={
    'Park Name': 'Name'
})

# Drop rows with missing latitude or longitude
cleaned_df = cleaned_df.dropna(subset=['Latitude', 'Longitude'])

# Show the cleaned data
cleaned_df.head()
# Out:
#                                                 Name   Latitude  Longitude
# 0                                  Puttenahalli park  13.110557  77.580365
# 1  SFS 208 Opp to Mother Dairy and 1st Main Park ...  13.099303  77.574431
# 2  SFS 208 Opp to Mother dairy 2nd Main P 208 2 P...  13.099846  77.575161
# 3        SFS 407 1st and 3rd e 208 Main Park P 407 3  13.102118  77.573854
# 4  SFS 208 1st Main and 2nd Main Behind to House ...  13.099616  77.572693

# %%
import pandas as pd

# Load the uploaded CSV file
file_path = "bbmp-parks-2016.csv"
df = pd.read_csv(file_path)

# Display the first few rows to understand the structure
df.head()
# Out:
#    Ward No         Ward Name Sub Division   Division Assembly Constituency  \
# 0        2  Chowdeswari Ward    Yelahanka  Yelahanka             Yelahanka
# 1        3            Atturu    Yelahanka  Yelahanka             Yelahanka
# 2        3            Atturu    Yelahanka  Yelahanka             Yelahanka
# 3        3            Atturu    Yelahanka  Yelahanka             Yelahanka
# 4        3            Atturu    Yelahanka  Yelahanka             Yelahanka
#
#    Zone Name                                          Park Name  Latitude   \
# 0  Yelahanka                                  Puttenahalli park  13.110557
# 1  Yelahanka  SFS 208 Opp to Mother Dairy and 1st Main Park ...  13.099303
# 2  Yelahanka  SFS 208 Opp to Mother dairy 2nd Main P 208 2 P...  13.099846
# 3  Yelahanka        SFS 407 1st and 3rd e 208 Main Park P 407 3  13.102118
# 4  Yelahanka  SFS 208 1st Main and 2nd Main Behind to House ...  13.099616
#
# ...

# %%
# Keep only the necessary columns and rename them
cleaned_df = df[['Park Name', 'Latitude', 'Longitude']].rename(columns={
    'Park Name': 'Name'
})

# Drop rows with missing latitude or longitude
cleaned_df = cleaned_df.dropna(subset=['Latitude', 'Longitude'])

# Show the cleaned data
cleaned_df.head()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[9], line 2
#       1 # Keep only the necessary columns and rename them
# ----> 2 cleaned_df = df[['Park Name', 'Latitude', 'Longitude']].rename(columns={
#       3     'Park Name': 'Name'
#       4 })
#       6 # Drop rows with missing latitude or longitude
#       7 cleaned_df = cleaned_df.dropna(subset=['Latitude', 'Longitude'])
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\pandas\core\frame.py:4108, in DataFrame.__getitem__(self, key)
#    4106     if is_iterator(key):
#    4107         key = list(key)
# -> 4108     indexer = self.columns._get_indexer_strict(key, "columns")[1]
#    4110 # take() does not accept boolean indexers
#    4111 if getattr(indexer, "dtype", None) == bool:
#
# ...

# %%
# Strip whitespace from column names
df.columns = df.columns.str.strip()

# Now select and rename the relevant columns
cleaned_df = df[['Park Name', 'Latitude', 'Longitude']].rename(columns={
    'Park Name': 'Name'
})

# Drop rows with missing latitude or longitude
cleaned_df = cleaned_df.dropna(subset=['Latitude', 'Longitude'])
cleaned_df.to_csv("cleaned_parks.csv", index=False)

# Show the cleaned data
cleaned_df.head()
# Out:
#                                                 Name   Latitude  Longitude
# 0                                  Puttenahalli park  13.110557  77.580365
# 1  SFS 208 Opp to Mother Dairy and 1st Main Park ...  13.099303  77.574431
# 2  SFS 208 Opp to Mother dairy 2nd Main P 208 2 P...  13.099846  77.575161
# 3        SFS 407 1st and 3rd e 208 Main Park P 407 3  13.102118  77.573854
# 4  SFS 208 1st Main and 2nd Main Behind to House ...  13.099616  77.572693

# %%
import pandas as pd

# Load the original file
df = pd.read_csv("bbmp-parks-2016.csv")

# Strip extra spaces from column names
df.columns = df.columns.str.strip()

# Keep only the needed columns and rename
cleaned_df = df[['Park Name', 'Latitude', 'Longitude']].rename(columns={
    'Park Name': 'Name'
})

# Drop rows with missing coordinates
cleaned_df = cleaned_df.dropna(subset=['Latitude', 'Longitude'])

# Save to new CSV
cleaned_df.to_csv("cleaned_parks.csv", index=False)
